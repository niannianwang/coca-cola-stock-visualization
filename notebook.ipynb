# %%
import pandas as pd

# %%
df = pd.read_csv("./static/Coca-Cola_stock_history.csv")
df
# Out:
#                             Date       Open       High        Low      Close  \
# 0                     1962-01-02   0.050016   0.051378   0.050016   0.050016
# 1                     1962-01-03   0.049273   0.049273   0.048159   0.048902
# 2                     1962-01-04   0.049026   0.049645   0.049026   0.049273
# 3                     1962-01-05   0.049273   0.049892   0.048035   0.048159
# 4                     1962-01-08   0.047787   0.047787   0.046735   0.047664
# ...                          ...        ...        ...        ...        ...
# 15306  2022-10-20 00:00:00-04:00  55.770000  55.919998  54.959999  55.080002
# 15307  2022-10-21 00:00:00-04:00  55.000000  56.110001  54.990002  55.959999
# 15308  2022-10-24 00:00:00-04:00  56.639999  57.730000  56.570000  57.570000
# 15309  2022-10-25 00:00:00-04:00  59.040001  59.110001  57.750000  58.950001
# 15310  2022-10-26 00:00:00-04:00  59.009998  59.779999  58.860001  59.389999
#
#          Volume  Dividends  Stock Splits
# ...

# %%
def clean_text(text):
    if len(text) > 10:
        return text[:10].strip()
    return text.strip()

# %%
df['Date'] = df['Date'].apply(clean_text)

# %%
df
# Out:
#              Date       Open       High        Low      Close    Volume  \
# 0      1962-01-02   0.050016   0.051378   0.050016   0.050016    806400
# 1      1962-01-03   0.049273   0.049273   0.048159   0.048902   1574400
# 2      1962-01-04   0.049026   0.049645   0.049026   0.049273    844800
# 3      1962-01-05   0.049273   0.049892   0.048035   0.048159   1420800
# 4      1962-01-08   0.047787   0.047787   0.046735   0.047664   2035200
# ...           ...        ...        ...        ...        ...       ...
# 15306  2022-10-20  55.770000  55.919998  54.959999  55.080002  16905100
# 15307  2022-10-21  55.000000  56.110001  54.990002  55.959999  15028000
# 15308  2022-10-24  56.639999  57.730000  56.570000  57.570000  17416700
# 15309  2022-10-25  59.040001  59.110001  57.750000  58.950001  28829900
# 15310  2022-10-26  59.009998  59.779999  58.860001  59.389999  15831400
#
#        Dividends  Stock Splits
# 0            0.0             0
# 1            0.0             0
# ...

# %%
df.to_csv("./static/Coca-Cola_stock_history.csv", index=False)
